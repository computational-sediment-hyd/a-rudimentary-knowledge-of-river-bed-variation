# %% [markdown]
# # 河床変動の応用-平面的な河床変動

# %% [markdown]
# ここまでは縦断的な河床変動を取り扱ってきたが実河川では平面的な河床変動も生じている。

# %% [markdown]
# ## 砂州

# %% [markdown]
#  - 単列砂州（交互砂州）

# %%
from IPython.display import IFrame
IFrame("https://maps.gsi.go.jp/?hc=hic#15/33.938447/134.621229/&base=ort&ls=ort%7Cgazo4&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s0m0f0" ,width=800,height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://maps.gsi.go.jp/?hc=hic#15/33.938447/134.621229/&base=ort&ls=ort%7Cgazo4&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s0m0f0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
#  - 複列砂州
#
# 画像を右クリックで再生を選択
# <video width="640" height="360" src="https://storage.googleapis.com/planet-t2/kamanashi-multiplesandbar-2EXwE13WR/movie.mp4" />

# %% [markdown]
#  - 多列砂州

# %%
from IPython.display import IFrame
IFrame("https://maps.gsi.go.jp/?hc=hic#16/35.414428/132.809687/&base=ort&ls=ort%7Cgazo4&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s0m0f0" ,width=500,height=400)
# Out:
#         <iframe
#             width="500"
#             height="400"
#             src="https://maps.gsi.go.jp/?hc=hic#16/35.414428/132.809687/&base=ort&ls=ort%7Cgazo4&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s0m0f0"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("https://www.google.com/maps/embed?pb=!4v1589436014790!6m8!1m7!1svjLVOaONp8rfG7vPXg-Jsg!2m2!1d35.41611159377166!2d132.8138269050567!3f57.704570097648585!4f-6.681007775900639!5f0.7820865974627469" ,width=800,height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="https://www.google.com/maps/embed?pb=!4v1589436014790!6m8!1m7!1svjLVOaONp8rfG7vPXg-Jsg!2m2!1d35.41611159377166!2d132.8138269050567!3f57.704570097648585!4f-6.681007775900639!5f0.7820865974627469"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
#  - 砂州の形状は川幅と水深の比によって決定する。
# <div align="center">
# <img src="fig/sandbar.jpg" width="500">
# </div>
# 「21世紀の河川学」より引用

# %% [markdown]
#  - 砂州は出水ごとに移動するが列数は変わらない。これも動的平衡状態。
#  - 砂州はある程度人為的にデザインできる。
#      * 川を単なる水路と考えると川幅は最低限で良い。（例えば、都市河川）
#      * 最近は可能な限り川幅を広くとり、自由な変動を許容するような河道設計が望まれている。

# %% [markdown]
# ## 蛇行
#
#  - 砂州を長期的にみると蛇行になる。

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('qYKj0yZASMo', width=400)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gYg1MSOK1Ck', width=400)

# %% [markdown]
#  - 川はまっすぐ流れることができない。

# %% [markdown]
#  - 多くの日本の川はなぜ蛇行しないのか？→堤防、護岸があるから。堤防、護岸は川の変動を制限する役割を持っている。
#  - 設計外力を超える出水の場合、氾濫が起こったりする。川側からみると自由に流れているだけ。

# %% [markdown]
#  - 令和元年東日本台風の被災事例：旧河道部分で氾濫が発生

# %%
from IPython.display import IFrame
IFrame("https://maps.gsi.go.jp/?hc=hic#13/36.43689/140.424757/&base=ort&ls=ort%7C20191012typhoon19_naka_1014dansaizu&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s1m0f0&vs2=f0&sync=1&ls2=std%7Clcmfc2&blend2=0&disp2=11" ,width=800,height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://maps.gsi.go.jp/?hc=hic#13/36.43689/140.424757/&base=ort&ls=ort%7C20191012typhoon19_naka_1014dansaizu&blend=0&disp=11&vs=c1j0h0k0l0u0t0z0r0s1m0f0&vs2=f0&sync=1&ls2=std%7Clcmfc2&blend2=0&disp2=11"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## 数値計算
#  - 前章の一次元の式とほとんど変わらない。
#
# $$
# \begin{align}
#     (1-\lambda)\frac{\partial z_{b}}{\partial t}+\frac{\partial q_{bx}}{\partial x} + \frac{\partial q_{by}}{\partial y} &= 0 \\
#      \boldsymbol{q_b}(q_{bx},q_{by}) &= {\rm func} ( \boldsymbol{\tau_*})
# \end{align}
# $$

# %% [markdown]
#  - これだけでは十分ではない。
#
#     * 局所勾配の影響：局所の内部摩擦角が安息角に近くなるとわずかな掃流力で土砂が移動する。
#     * 斜面崩壊 : 浸食により河岸勾配が安息角を超えると崩壊が起こる。（その場の掃流力とは無関係）
#
# を考慮する必要がある。
